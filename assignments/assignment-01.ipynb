# %%
print(f"Name: Fatima \n Father's Name: Ali \n Date of Birth: 15-08-2002", sep="  " )
# Out:
# Name: Fatima
#  Father's Name: Ali
#  Date of Birth: 15-08-2002

# %%
print("Name:", "Fatima", sep="  ")
print("Father's Name:", "Ali", sep="  ")
# Out:
# Name:  Fatima
# Father's Name:  Ali

# %%
name = " Fatima"
age = 27
interest ="AI"

print(f"Assalam-o-Alaikum,  My name is {name} and my age is {age} my interest is {interest}")
# Out:
# Assalam-o-Alaikum,  My name is Sehar Fatima and my age is 27 my interest is AI

# %%
a = 10
b = 3

print("Arithmetic Operator")
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Floor Division:", a // b)
print("Exponentiation:", a ** b)

print("\nLogical Operator")
x = True
y = False

print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)

print("\nRelational (Comparison) Operators")
print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a < b:", a < b)
print("a >= b:", a >= b)
print("a <= b:", a <= b)

print("\nAssignment Operators")
c = a
print("c = a:", c)

c += b
print("c += b:", c)

c -= b
print("c -= b:", c)

c *= b
print("c *= b:", c)

c /= b
print("c /= b:", c)

c %= b
print("c %= b:", c)

c //= b
print("c //= b:", c)

c **= b
print("c **= b:", c)

print("\nIdentity Operators")
print("a is b:", a is b)
print("a is not b:", a is not b)

print("\nMembership Operators")
my_list = [1, 2, 3, 10]

print("a in my_list:", a in my_list)
print("b not in my_list:", b not in my_list)
# Out:
# Arithmetic Operator
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Modulus: 1
# Floor Division: 3
# Exponentiation: 1000
#
# Logical Operator
# x and y: False
# x or y: True
# not x: False
#
# Relational (Comparison) Operators
# a == b: False
# a != b: True
# a > b: True
# a < b: False
# a >= b: True
# a <= b: False
#
# Assignment Operators
# c = a: 10
# c += b: 13
# c -= b: 10
# c *= b: 30
# c /= b: 10.0
# c %= b: 1.0
# c //= b: 0.0
# c **= b: 0.0
#
# Identity Operators
# a is b: False
# a is not b: True
#
# Membership Operators
# a in my_list: True
# b not in my_list: False

# %%
math_marks = 98
islamiat_marks= 99
english_marks = 92

total_marks_available = 300
total_marks_obtained = math_marks + islamiat_marks + english_marks

percentage = (total_marks_obtained / total_marks_available ) * 100

print(f"The percentage is {percentage}")
# Out:
# The percentage is 96.33333333333334
